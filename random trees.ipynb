# %% [raw]
# grade = read.csv("grade.csv", header= TRUE)

# %%
grade <- read.csv("/home/dell/R_programming/grade.csv", header = TRUE, sep=",")
grade
# Out:
#     final_grade age address studytime schoolsup famsup paid absences
# 1   3.0         18  U       2         yes       no     no    6
# 2   3.0         17  U       2         no        yes    no    4
# 3   5.0         15  U       2         yes       no     yes  10
# 4   7.5         15  U       3         no        yes    yes   2
# 5   5.0         16  U       2         no        yes    yes   4
# 6   7.5         16  U       2         no        yes    yes  10
# 7   5.5         16  U       2         no        no     no    0
# 8   3.0         17  U       2         yes       yes    no    6
# 9   9.5         15  U       2         no        yes    yes   0
# 10  7.5         15  U       2         no        yes    yes   0
# 11  4.5         15  U       2         no        yes    yes   0
# 12  6.0         15  U       3         no        yes    no    4
# 13  7.0         15  U       1         no        yes    yes   2
# 14  5.5         15  U       2         no        yes    yes   2
# ...
